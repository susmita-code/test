# %% [markdown]
# <a href="https://colab.research.google.com/github/susmita-code/test/blob/main/image%2Cread%2Cresize%2Ccrop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np

img = cv2.imread("/C360_2018-08-05-18-27-42-772.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1733x1155 at 0x7F5056D633D0>

# %%
print(img.shape)
width , height = 400,400
imgResize= cv2.resize(img,(width,height))
cv2_imshow(imgResize)
print(imgResize.shape)
# Out:
# (1155, 1733, 3)
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F504D80B9A0>
# (400, 400, 3)

# %%
imgCropped= img[410:550, 665:790]
cv2_imshow(imgCropped)
# Out:
# <PIL.Image.Image image mode=RGB size=125x140 at 0x7F504D8253D0>
